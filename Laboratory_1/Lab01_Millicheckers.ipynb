# %% [markdown]
# <a href="https://colab.research.google.com/github/airon14/AIDL/blob/main/Laboratory_1/Lab01_Millicheckers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# %%
iris = pd.read_csv("/content/iris.data")

# %%
iris.columns = ['Sepal length cm', 'Sepal width cm', 'Petal length cm', 'Petal width cm', 'species']

# %%
iris.shape
# Out:
# (149, 5)

# %%
iris.head()
# Out:
#    Sepal length cm  Sepal width cm  Petal length cm  Petal width cm  \
# 0              4.9             3.0              1.4             0.2
# 1              4.7             3.2              1.3             0.2
# 2              4.6             3.1              1.5             0.2
# 3              5.0             3.6              1.4             0.2
# 4              5.4             3.9              1.7             0.4
#
#        species
# 0  Iris-setosa
# 1  Iris-setosa
# 2  Iris-setosa
# 3  Iris-setosa
# 4  Iris-setosa

# %%
iris.tail()
# Out:
#      Sepal length cm  Sepal width cm  ...  Petal width cm         species
# 144              6.7             3.0  ...             2.3  Iris-virginica
# 145              6.3             2.5  ...             1.9  Iris-virginica
# 146              6.5             3.0  ...             2.0  Iris-virginica
# 147              6.2             3.4  ...             2.3  Iris-virginica
# 148              5.9             3.0  ...             1.8  Iris-virginica
#
# [5 rows x 5 columns]

# %%
iris.describe()
# Out:
#        Sepal length cm  Sepal width cm  Petal length cm  Petal width cm
# count       149.000000      149.000000       149.000000      149.000000
# mean          5.848322        3.051007         3.774497        1.205369
# std           0.828594        0.433499         1.759651        0.761292
# min           4.300000        2.000000         1.000000        0.100000
# 25%           5.100000        2.800000         1.600000        0.300000
# 50%           5.800000        3.000000         4.400000        1.300000
# 75%           6.400000        3.300000         5.100000        1.800000
# max           7.900000        4.400000         6.900000        2.500000

# %%
iris.columns
# Out:
# Index(['Sepal length cm', 'Sepal width cm', 'Petal length cm',
#        'Petal width cm', 'species'],
#       dtype='object')

# %%
iris['species'].value_counts()
# Out:
# Iris-versicolor    50
# Iris-virginica     50
# Iris-setosa        49
# Name: species, dtype: int64

# %%
iris.isnull().sum()
# Out:
# Sepal length cm    0
# Sepal width cm     0
# Petal length cm    0
# Petal width cm     0
# species            0
# dtype: int64

# %%
iris.corr()
# Out:
#                  Sepal length cm  ...  Petal width cm
# Sepal length cm         1.000000  ...        0.816971
# Sepal width cm         -0.103784  ...       -0.350733
# Petal length cm         0.871283  ...        0.962314
# Petal width cm          0.816971  ...        1.000000
#
# [4 rows x 4 columns]

# %%
fig = plt.subplots(figsize=(8,8))
plt.scatter(iris['Sepal length cm'], iris['Sepal width cm'])
plt.xlabel('SepalLength')
plt.ylabel('SepalWidth')
plt.show()

# %%
fig = plt.subplots(figsize=(10,10))
plt.scatter(iris['Petal length cm'], iris['Petal width cm'])
plt.xlabel('Petal Length')
plt.ylabel('Petal Width')
plt.show()

# %%
fig = plt.subplots(figsize=(10,10))
plt.scatter(iris['Sepal length cm'], iris['Sepal width cm'])
plt.xlabel('Petal Length')
plt.ylabel('Sepal Width')
plt.show()

# %%
plt.figure(figsize=(9,6)) 
sns.heatmap(iris.corr(),annot=True,cmap='magma') 
plt.show()

# %% [markdown]
# There is a high correlation between the petal length and petal width.

# %%
g = sns.pairplot(iris, hue='species', palette='rocket')
plt.show()

# %% [markdown]
# Iris-setosa is different from the other two species.

# %%
import tensorflow as tf
from tensorflow.keras.layers import Activation
from tensorflow.nn import sigmoid, tanh, softmax, relu, leaky_relu
from tensorflow.keras.optimizers import Adam, SGD, RMSprop
from tensorflow.keras.losses import MSE, MAE
from tensorflow.keras.utils import to_categorical

import keras
from keras.models import Sequential
from keras.layers import Dense, Activation

# %%
l_encoder = LabelEncoder()
iris["species"] = l_encoder.fit_transform(iris["species"])
species = pd.DataFrame({'species': ['Iris-setosa', 'Iris-versicolor', 'Iris-virginica']})

# %%
train, test = train_test_split(iris, test_size = 0.2)
trainX = train[['Sepal length cm','Sepal width cm','Petal length cm','Petal width cm']]
trainY=train.species
testX= test[['Sepal length cm','Sepal width cm','Petal length cm','Petal width cm']]
testY =test.species  
trainX.head()
# Out:
#      Sepal length cm  Sepal width cm  Petal length cm  Petal width cm
# 50               6.4             3.2              4.5             1.5
# 46               4.6             3.2              1.4             0.2
# 16               5.1             3.5              1.4             0.3
# 104              7.6             3.0              6.6             2.1
# 135              6.3             3.4              5.6             2.4

# %%
loss, accuracy = model1.evaluate(testX, testY , verbose=0)
print('Test loss:', loss)
print('Test accuracy:', accuracy)
# Out:
# Test loss: 3.0996968746185303
# Test accuracy: 0.0

# %%
loss, accuracy = model2.evaluate(testX, testY , verbose=0)
print('Test loss:', loss)
print('Test accuracy:', accuracy)
# Out:
# Test loss: 3.4769766330718994
# Test accuracy: 0.30000001192092896

# %%
loss, accuracy = model3.evaluate(testX, testY , verbose=0)
print('Test loss:', loss)
print('Test accuracy:', accuracy)
# Out:
# Test loss: 1.292535424232483
# Test accuracy: 0.36666667461395264

# %%
loss, accuracy = model4.evaluate(testX, testY , verbose=0)
print('Test loss:', loss)
print('Test accuracy:', accuracy)
# Out:
# Test loss: 1.1155915260314941
# Test accuracy: 0.699999988079071

# %%
loss, accuracy = model5.evaluate(testX, testY , verbose=0)
print('Test loss:', loss)
print('Test accuracy:', accuracy)
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_test_function.<locals>.test_function at 0x7f38b3e2c8c0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Test loss: 2.4214701652526855
# Test accuracy: 0.30000001192092896

# %%
loss, accuracy = model6.evaluate(testX, testY , verbose=0)
print('Test loss:', loss)
print('Test accuracy:', accuracy)
# Out:
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_test_function.<locals>.test_function at 0x7f38af927d40> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Test loss: 1.3695545196533203
# Test accuracy: 0.3333333432674408

# %%
loss, accuracy = model7.evaluate(testX, testY , verbose=0)
print('Test loss:', loss)
print('Test accuracy:', accuracy)
# Out:
# Test loss: 1.1101949214935303
# Test accuracy: 0.699999988079071

# %%
loss, accuracy = model8.evaluate(testX, testY , verbose=0)
print('Test loss:', loss)
print('Test accuracy:', accuracy)
# Out:
# Test loss: 1.0501172542572021
# Test accuracy: 0.36666667461395264

# %%
loss, accuracy = model9.evaluate(testX, testY , verbose=0)
print('Test loss:', loss)
print('Test accuracy:', accuracy)
# Out:
# Test loss: 1.059901475906372
# Test accuracy: 0.3333333432674408

# %%
model1 = Sequential()
model1.add(Dense(units=4, input_dim=4))
model1.add(Dense(8, activation='relu'))
model1.add(Dense(3, activation='softmax'))
l_rate = 0.06
model1.compile(optimizer=SGD(learning_rate=l_rate), loss='SparseCategoricalCrossentropy', metrics = ['accuracy'])
model1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 4)                 20
#
#  dense_1 (Dense)             (None, 8)                 40
#
#  dense_2 (Dense)             (None, 3)                 27
#
# ...
# Total params: 87
# Trainable params: 87
# Non-trainable params: 0
# _________________________________________________________________

# %%
model2 = Sequential()
model2.add(Dense(units=4, input_dim=4))
model2.add(Dense(6, activation='relu'))
model2.add(Dense(3, activation='softmax'))
l_rate = 0.01
model2.compile(optimizer=SGD(learning_rate=l_rate), loss='SparseCategoricalCrossentropy', metrics = ['accuracy'])
model2.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_3 (Dense)             (None, 4)                 20
#
#  dense_4 (Dense)             (None, 6)                 30
#
#  dense_5 (Dense)             (None, 3)                 21
#
# ...
# Total params: 71
# Trainable params: 71
# Non-trainable params: 0
# _________________________________________________________________

# %%
model3 = Sequential()
model3.add(Dense(units=4, input_dim=4))
model3.add(Dense(20, activation='relu'))
model3.add(Dense(3, activation='softmax'))
l_rate=0.06
model3.compile(optimizer=SGD(learning_rate=l_rate), loss='SparseCategoricalCrossentropy', metrics = ['accuracy'])
model3.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_6 (Dense)             (None, 4)                 20
#
#  dense_7 (Dense)             (None, 20)                100
#
#  dense_8 (Dense)             (None, 3)                 63
#
# ...
# Total params: 183
# Trainable params: 183
# Non-trainable params: 0
# _________________________________________________________________

# %%
model4 = Sequential()
model4.add(Dense(units=4, input_dim=4))
model4.add(Dense(6, activation='relu'))
model4.add(Dense(8, activation='relu'))
model4.add(Dense(3, activation='softmax'))
l_rate=0.01
model4.compile(optimizer=SGD(learning_rate=l_rate), loss='SparseCategoricalCrossentropy', metrics = ['accuracy'])
model4.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_9 (Dense)             (None, 4)                 20
#
#  dense_10 (Dense)            (None, 6)                 30
#
#  dense_11 (Dense)            (None, 8)                 56
#
#  dense_12 (Dense)            (None, 3)                 27
#
# ...
# Total params: 133
# Trainable params: 133
# Non-trainable params: 0
# _________________________________________________________________

# %%
model5 = Sequential()
model5.add(Dense(units=4, input_dim=4))
model5.add(Dense(6, activation='relu'))
model5.add(Dense(8, activation='relu'))
model5.add(Dense(10, activation='relu'))
model5.add(Dense(3, activation='softmax'))
l_rate=0.08
model5.compile(optimizer=SGD(learning_rate=l_rate), loss='SparseCategoricalCrossentropy', metrics = ['accuracy'])
model5.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_13 (Dense)            (None, 4)                 20
#
#  dense_14 (Dense)            (None, 6)                 30
#
#  dense_15 (Dense)            (None, 8)                 56
#
#  dense_16 (Dense)            (None, 10)                90
#
#  dense_17 (Dense)            (None, 3)                 33
#
# ...
# Total params: 229
# Trainable params: 229
# Non-trainable params: 0
# _________________________________________________________________

# %%
model6 = Sequential()
model6.add(Dense(units=4, input_dim=4))
model6.add(Dense(3, activation='relu'))
model6.add(Dense(6, activation='relu'))
model6.add(Dense(3, activation='softmax'))
l_rate=0.02
model6.compile(optimizer=SGD(learning_rate=l_rate), loss='SparseCategoricalCrossentropy', metrics = ['accuracy'])
model6.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_18 (Dense)            (None, 4)                 20
#
#  dense_19 (Dense)            (None, 3)                 15
#
#  dense_20 (Dense)            (None, 6)                 24
#
#  dense_21 (Dense)            (None, 3)                 21
#
# ...
# Total params: 80
# Trainable params: 80
# Non-trainable params: 0
# _________________________________________________________________

# %%
model7 = Sequential()
model7.add(Dense(units=4, input_dim=4))
model7.add(Dense(8, activation='relu'))
model7.add(Dense(18, activation='relu'))
model7.add(Dense(3, activation='softmax'))
l_rate=0.02
model7.compile(optimizer=SGD(learning_rate=l_rate), loss='SparseCategoricalCrossentropy', metrics = ['accuracy'])
model7.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_22 (Dense)            (None, 4)                 20
#
#  dense_23 (Dense)            (None, 8)                 40
#
#  dense_24 (Dense)            (None, 18)                162
#
#  dense_25 (Dense)            (None, 3)                 57
#
# ...
# Total params: 279
# Trainable params: 279
# Non-trainable params: 0
# _________________________________________________________________

# %%
model8 = Sequential()
model8.add(Dense(units=4, input_dim=4))
model8.add(Dense(8, activation='relu'))
model8.add(Dense(10, activation='relu'))
model8.add(Dense(12, activation='relu'))
model8.add(Dense(3, activation='softmax'))
l_rate=0.05
model8.compile(optimizer=SGD(learning_rate=l_rate), loss='SparseCategoricalCrossentropy', metrics = ['accuracy'])
model8.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_26 (Dense)            (None, 4)                 20
#
#  dense_27 (Dense)            (None, 8)                 40
#
#  dense_28 (Dense)            (None, 10)                90
#
#  dense_29 (Dense)            (None, 12)                132
#
#  dense_30 (Dense)            (None, 3)                 39
#
# ...
# Total params: 321
# Trainable params: 321
# Non-trainable params: 0
# _________________________________________________________________

# %%
model9 = Sequential()
model9.add(Dense(units=4, input_dim=4))
model9.add(Dense(4, activation='relu'))
model9.add(Dense(8, activation='relu'))
model9.add(Dense(12, activation='relu'))
model9.add(Dense(16, activation='relu'))
model9.add(Dense(3, activation='softmax'))
l_rate=0.09
model9.compile(optimizer=SGD(learning_rate=l_rate), loss='SparseCategoricalCrossentropy', metrics = ['accuracy'])
model9.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_31 (Dense)            (None, 4)                 20
#
#  dense_32 (Dense)            (None, 4)                 20
#
#  dense_33 (Dense)            (None, 8)                 40
#
#  dense_34 (Dense)            (None, 12)                108
#
#  dense_35 (Dense)            (None, 16)                208
#
#  dense_36 (Dense)            (None, 3)                 51
#
# ...
# Total params: 447
# Trainable params: 447
# Non-trainable params: 0
# _________________________________________________________________

# %%
history1=model1.fit(trainX, trainY, epochs=50, batch_size=1)
# Out:
# Epoch 1/50
# 119/119 [==============================] - 2s 4ms/step - loss: 0.7572 - accuracy: 0.6387
# Epoch 2/50
# 119/119 [==============================] - 0s 2ms/step - loss: 0.4628 - accuracy: 0.7983
# Epoch 3/50
# 119/119 [==============================] - 0s 2ms/step - loss: 0.3877 - accuracy: 0.7983
# Epoch 4/50
# 119/119 [==============================] - 0s 2ms/step - loss: 0.4196 - accuracy: 0.8235
# Epoch 5/50
# 119/119 [==============================] - 0s 2ms/step - loss: 0.3395 - accuracy: 0.8151
# Epoch 6/50
# 119/119 [==============================] - 0s 2ms/step - loss: 0.3427 - accuracy: 0.8487
# Epoch 7/50
# 119/119 [==============================] - 0s 2ms/step - loss: 0.3030 - accuracy: 0.8655
# Epoch 8/50
# 119/119 [==============================] - 0s 2ms/step - loss: 0.3325 - accuracy: 0.8739
# Epoch 9/50
# 119/119 [==============================] - 0s 3ms/step - loss: 0.3280 - accuracy: 0.8739
# Epoch 10/50
# ...

# %%
history2=model2.fit(trainX, trainY, epochs=50, batch_size=1)
# Out:
# Epoch 1/50
# 119/119 [==============================] - 0s 1ms/step - loss: 1.2755 - accuracy: 0.3613
# Epoch 2/50
# 119/119 [==============================] - 0s 1ms/step - loss: 1.1008 - accuracy: 0.3529
# Epoch 3/50
# 119/119 [==============================] - 0s 1ms/step - loss: 1.0996 - accuracy: 0.2857
# Epoch 4/50
# 119/119 [==============================] - 0s 1ms/step - loss: 1.0990 - accuracy: 0.3361
# Epoch 5/50
# 119/119 [==============================] - 0s 1ms/step - loss: 1.0985 - accuracy: 0.3193
# Epoch 6/50
# 119/119 [==============================] - 0s 1ms/step - loss: 1.0980 - accuracy: 0.2773
# Epoch 7/50
# 119/119 [==============================] - 0s 1ms/step - loss: 1.0983 - accuracy: 0.3025
# Epoch 8/50
# 119/119 [==============================] - 0s 1ms/step - loss: 1.0984 - accuracy: 0.3193
# Epoch 9/50
# 119/119 [==============================] - 0s 1ms/step - loss: 1.0983 - accuracy: 0.3109
# Epoch 10/50
# ...

# %%
history3 = model3.fit(trainX, trainY, epochs = 50, batch_size = 1)
# Out:
# Epoch 1/50
# 119/119 [==============================] - 0s 1ms/step - loss: 0.7315 - accuracy: 0.6303
# Epoch 2/50
# 119/119 [==============================] - 0s 1ms/step - loss: 0.4733 - accuracy: 0.7311
# Epoch 3/50
# 119/119 [==============================] - 0s 1ms/step - loss: 0.4302 - accuracy: 0.7647
# Epoch 4/50
# 119/119 [==============================] - 0s 1ms/step - loss: 0.3635 - accuracy: 0.8403
# Epoch 5/50
# 119/119 [==============================] - 0s 1ms/step - loss: 0.3840 - accuracy: 0.8319
# Epoch 6/50
# 119/119 [==============================] - 0s 1ms/step - loss: 0.4448 - accuracy: 0.7983
# Epoch 7/50
# 119/119 [==============================] - 0s 1ms/step - loss: 0.4430 - accuracy: 0.7647
# Epoch 8/50
# 119/119 [==============================] - 0s 1ms/step - loss: 0.2826 - accuracy: 0.9076
# Epoch 9/50
# 119/119 [==============================] - 0s 1ms/step - loss: 0.4083 - accuracy: 0.8151
# Epoch 10/50
# ...

# %%
history4 = model4.fit(trainX, trainY, epochs = 50, batch_size = 1)
# Out:
# Epoch 1/50
# 119/119 [==============================] - 1s 1ms/step - loss: 0.7422 - accuracy: 0.6050
# Epoch 2/50
# 119/119 [==============================] - 0s 1ms/step - loss: 0.4868 - accuracy: 0.7731
# Epoch 3/50
# 119/119 [==============================] - 0s 1ms/step - loss: 0.4192 - accuracy: 0.7815
# Epoch 4/50
# 119/119 [==============================] - 0s 1ms/step - loss: 0.3714 - accuracy: 0.8235
# Epoch 5/50
# 119/119 [==============================] - 0s 1ms/step - loss: 0.3300 - accuracy: 0.8571
# Epoch 6/50
# 119/119 [==============================] - 0s 1ms/step - loss: 0.3438 - accuracy: 0.8487
# Epoch 7/50
# 119/119 [==============================] - 0s 1ms/step - loss: 0.3029 - accuracy: 0.8824
# Epoch 8/50
# 119/119 [==============================] - 0s 1ms/step - loss: 0.3280 - accuracy: 0.8151
# Epoch 9/50
# 119/119 [==============================] - 0s 1ms/step - loss: 0.2639 - accuracy: 0.8824
# Epoch 10/50
# ...

# %%
history5 = model5.fit(trainX, trainY, epochs = 50, batch_size = 1)
# Out:
# Epoch 1/50
# 119/119 [==============================] - 1s 1ms/step - loss: 1.0450 - accuracy: 0.4622
# Epoch 2/50
# 119/119 [==============================] - 0s 1ms/step - loss: 0.7474 - accuracy: 0.6134
# Epoch 3/50
# 119/119 [==============================] - 0s 1ms/step - loss: 0.5751 - accuracy: 0.6891
# Epoch 4/50
# 119/119 [==============================] - 0s 1ms/step - loss: 0.5330 - accuracy: 0.7227
# Epoch 5/50
# 119/119 [==============================] - 0s 1ms/step - loss: 0.5600 - accuracy: 0.7311
# Epoch 6/50
# 119/119 [==============================] - 0s 1ms/step - loss: 0.4672 - accuracy: 0.7059
# Epoch 7/50
# 119/119 [==============================] - 0s 1ms/step - loss: 0.4575 - accuracy: 0.7563
# Epoch 8/50
# 119/119 [==============================] - 0s 1ms/step - loss: 0.5759 - accuracy: 0.7143
# Epoch 9/50
# 119/119 [==============================] - 0s 1ms/step - loss: 0.4042 - accuracy: 0.7899
# Epoch 10/50
# ...

# %%
history6 = model6.fit(trainX, trainY, epochs = 50, batch_size = 1)
# Out:
# Epoch 1/50
# 119/119 [==============================] - 0s 1ms/step - loss: 0.7381 - accuracy: 0.6891
# Epoch 2/50
# 119/119 [==============================] - 0s 1ms/step - loss: 0.5289 - accuracy: 0.6807
# Epoch 3/50
# 119/119 [==============================] - 0s 1ms/step - loss: 0.4676 - accuracy: 0.7143
# Epoch 4/50
# 119/119 [==============================] - 0s 2ms/step - loss: 0.4373 - accuracy: 0.8067
# Epoch 5/50
# 119/119 [==============================] - 0s 1ms/step - loss: 0.4197 - accuracy: 0.7731
# Epoch 6/50
# 119/119 [==============================] - 0s 1ms/step - loss: 0.3967 - accuracy: 0.7983
# Epoch 7/50
# 119/119 [==============================] - 0s 2ms/step - loss: 0.3476 - accuracy: 0.8235
# Epoch 8/50
# 119/119 [==============================] - 0s 1ms/step - loss: 0.3000 - accuracy: 0.8824
# Epoch 9/50
# 119/119 [==============================] - 0s 1ms/step - loss: 0.3650 - accuracy: 0.8403
# Epoch 10/50
# ...

# %%
history7 = model7.fit(trainX, trainY, epochs = 50, batch_size = 1)
# Out:
# Epoch 1/50
# 119/119 [==============================] - 0s 1ms/step - loss: 0.7677 - accuracy: 0.6218
# Epoch 2/50
# 119/119 [==============================] - 0s 1ms/step - loss: 0.5484 - accuracy: 0.6891
# Epoch 3/50
# 119/119 [==============================] - 0s 1ms/step - loss: 0.5383 - accuracy: 0.6975
# Epoch 4/50
# 119/119 [==============================] - 0s 1ms/step - loss: 0.4900 - accuracy: 0.6975
# Epoch 5/50
# 119/119 [==============================] - 0s 1ms/step - loss: 0.4656 - accuracy: 0.7395
# Epoch 6/50
# 119/119 [==============================] - 0s 1ms/step - loss: 0.4425 - accuracy: 0.7899
# Epoch 7/50
# 119/119 [==============================] - 0s 1ms/step - loss: 0.4249 - accuracy: 0.7983
# Epoch 8/50
# 119/119 [==============================] - 0s 1ms/step - loss: 0.4101 - accuracy: 0.7647
# Epoch 9/50
# 119/119 [==============================] - 0s 1ms/step - loss: 0.4319 - accuracy: 0.7479
# Epoch 10/50
# ...

# %%
history8 = model8.fit(trainX, trainY, epochs = 50, batch_size = 1)
# Out:
# Epoch 1/50
# 119/119 [==============================] - 1s 1ms/step - loss: 1.1137 - accuracy: 0.4370
# Epoch 2/50
# 119/119 [==============================] - 0s 2ms/step - loss: 0.6458 - accuracy: 0.7143
# Epoch 3/50
# 119/119 [==============================] - 0s 1ms/step - loss: 0.5300 - accuracy: 0.6723
# Epoch 4/50
# 119/119 [==============================] - 0s 1ms/step - loss: 0.4474 - accuracy: 0.7647
# Epoch 5/50
# 119/119 [==============================] - 0s 1ms/step - loss: 0.4363 - accuracy: 0.7311
# Epoch 6/50
# 119/119 [==============================] - 0s 1ms/step - loss: 0.3913 - accuracy: 0.7983
# Epoch 7/50
# 119/119 [==============================] - 0s 1ms/step - loss: 0.4242 - accuracy: 0.7563
# Epoch 8/50
# 119/119 [==============================] - 0s 1ms/step - loss: 0.3863 - accuracy: 0.7815
# Epoch 9/50
# 119/119 [==============================] - 0s 1ms/step - loss: 0.3861 - accuracy: 0.8151
# Epoch 10/50
# ...

# %%
history9 = model9.fit(trainX, trainY, epochs = 50, batch_size = 1)
# Out:
# Epoch 1/50
# 119/119 [==============================] - 1s 1ms/step - loss: 1.1088 - accuracy: 0.3866
# Epoch 2/50
# 119/119 [==============================] - 0s 1ms/step - loss: 0.8396 - accuracy: 0.6218
# Epoch 3/50
# 119/119 [==============================] - 0s 2ms/step - loss: 0.7330 - accuracy: 0.5882
# Epoch 4/50
# 119/119 [==============================] - 0s 1ms/step - loss: 0.5947 - accuracy: 0.7059
# Epoch 5/50
# 119/119 [==============================] - 0s 1ms/step - loss: 0.5577 - accuracy: 0.6387
# Epoch 6/50
# 119/119 [==============================] - 0s 2ms/step - loss: 0.7067 - accuracy: 0.6471
# Epoch 7/50
# 119/119 [==============================] - 0s 1ms/step - loss: 1.1523 - accuracy: 0.3277
# Epoch 8/50
# 119/119 [==============================] - 0s 1ms/step - loss: 1.1167 - accuracy: 0.2857
# Epoch 9/50
# 119/119 [==============================] - 0s 1ms/step - loss: 1.0259 - accuracy: 0.4118
# Epoch 10/50
# ...

# %%
plt.subplots(figsize=(15, 5))
plt.title('Loss Curve')
plt.subplot(1,2,1)
plt.plot(history1.history['loss'])
plt.ylabel('loss')
plt.xlabel('epoch')
plt.title('Model 1: Loss')
plt.subplot(1, 2, 2)
plt.plot(history1.history['accuracy'])
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.title('Model 1: Accuracy')
plt.show()

# %%
plt.subplots(figsize=(15, 5))
plt.title('Loss Curve')
plt.subplot(1,2,1)
plt.plot(history2.history['loss'])
plt.ylabel('loss')
plt.xlabel('epoch')
plt.title('Model 2: Loss')
plt.subplot(1, 2, 2)
plt.plot(history2.history['accuracy'])
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.title('Model 2: Accuracy')
plt.show()

# %%
plt.subplots(figsize=(15, 5))
plt.title('Loss Curve')
plt.subplot(1,2,1)
plt.plot(history3.history['loss'])
plt.ylabel('loss')
plt.xlabel('epoch')
plt.title('Model 3: Loss')
plt.subplot(1, 2, 2)
plt.plot(history3.history['accuracy'])
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.title('Model 3: Accuracy')
plt.show()

# %%
plt.subplots(figsize=(15, 5))
plt.title('Loss Curve')
plt.subplot(1,2,1)
plt.plot(history4.history['loss'])
plt.ylabel('loss')
plt.xlabel('epoch')
plt.title('Model 4: Loss')
plt.subplot(1, 2, 2)
plt.plot(history4.history['accuracy'])
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.title('Model 4: Accuracy')
plt.show()

# %%
plt.subplots(figsize=(15, 5))
plt.title('Loss Curve')
plt.subplot(1,2,1)
plt.plot(history5.history['loss'])
plt.ylabel('loss')
plt.xlabel('epoch')
plt.title('Model 5: Loss')
plt.subplot(1, 2, 2)
plt.plot(history5.history['accuracy'])
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.title('Model 5: Accuracy')
plt.show()

# %%
plt.subplots(figsize=(15, 5))
plt.title('Loss Curve')
plt.subplot(1,2,1)
plt.plot(history6.history['loss'])
plt.ylabel('loss')
plt.xlabel('epoch')
plt.title('Model 6: Loss')
plt.subplot(1, 2, 2)
plt.plot(history6.history['accuracy'])
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.title('Model 6: Accuracy')
plt.show()

# %%
plt.subplots(figsize=(15, 5))
plt.title('Loss Curve')
plt.subplot(1,2,1)
plt.plot(history7.history['loss'])
plt.ylabel('loss')
plt.xlabel('epoch')
plt.title('Model 7: Loss')
plt.subplot(1, 2, 2)
plt.plot(history7.history['accuracy'])
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.title('Model 7: Accuracy')
plt.show()

# %%
plt.subplots(figsize=(15, 5))
plt.title('Loss Curve')
plt.subplot(1,2,1)
plt.plot(history8.history['loss'])
plt.ylabel('loss')
plt.xlabel('epoch')
plt.title('Model 8: Loss')
plt.subplot(1, 2, 2)
plt.plot(history8.history['accuracy'])
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.title('Model 8: Accuracy')
plt.show()

# %%
plt.subplots(figsize=(15, 5))
plt.title('Loss Curve')
plt.subplot(1,2,1)
plt.plot(history9.history['loss'])
plt.ylabel('loss')
plt.xlabel('epoch')
plt.title('Model 9: Loss')
plt.subplot(1, 2, 2)
plt.plot(history9.history['accuracy'])
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.title('Model 9: Accuracy')
plt.show()

# %% [markdown]
# **Callbacks and TensorBoard**
